# %% [markdown]
# ### TPC7: Análise de dados: Alunos
#
# Descarregue o ficheiro de dados: `alunos.csv`
# Crie um programa em Python, conjunto de funções, que responda às seguintes questões:
# * Crie uma função que lê a informação do ficheiro para um modelo, previamente pensado em memória;
# * Crie uma função que calcula a distribuição dos alunos por curso;
# * Crie uma função que calcula a média das notas de cada aluno e acrescenta essa nova coluna no dataset em memória;
# * Considere os seguintes escalões de notas: E [1-4], D [5-8], C [9-12], B [13-16], A [17-20], acrescente uma coluna ao dataset com o escalão correspondente a cada aluno;
# * Crie uma distribuição dos alunos por escalão;
# * Crie uma função que apresenta na forma dum gráfico de linha uma distribuição;
# * Crie uma função que imprime na forma de uma tabela uma distribuição;
# * Especifique um programa que, ciclicamente, apresenta um menu com todas funcionalidades ao utilizador.

# %%
import TP7

# %%
Turma = TP7.le("alunos.csv")

Turma
# Out:
# [('a1', 'Aysha Melanie Gilberto', 'LEI', '12', '8', '19', '8'),
#  ('a2', 'Igor André Cantanhede', 'ENGFIS', '12', '16', '18', '20'),
#  ('a3', 'Laurénio Narciso', 'ENGFIS', '8', '14', '15', '14'),
#  ('a4', 'Jasnoor Casegas', 'LCC', '14', '20', '17', '11'),
#  ('a5', 'Tawseef Rebouças', 'ENGBIOM', '13', '14', '13', '17'),
#  ('a6', 'Eryk Clementino', 'LEI', '10', '19', '11', '14'),
#  ('a7', 'Ianna Noivo', 'ENGBIOM', '15', '15', '17', '16'),
#  ('a8', 'Ayla Thaissa Reina', 'ENGBIOM', '12', '8', '8', '18'),
#  ('a9', 'Cássia Viviane Coitã', 'ENGFIS', '19', '9', '14', '10'),
#  ('a10', 'Koby Vindima', 'LEI', '9', '14', '20', '13'),
#  ('a11', 'Gustavo Martim Hernandez', 'ENGBIOM', '11', '8', '14', '11'),
#  ('a12', 'Siddarta Beiriz', 'LEI', '17', '10', '16', '16'),
#  ('a13', 'Daniela Patrícia Montes', 'ENGBIOM', '15', '15', '18', '19'),
#  ('a14', 'Kaylla Pessego', 'LCC', '10', '14', '17', '15'),
#  ('a15', 'Bianca Cristina Primitivo', 'ENGBIOM', '16', '9', '18', '10'),
# ...

# %%
imprime = TP7.Imprime(Turma)

imprime
# Out:
#  |  anúmero   |           Nome            |   Curso    |   Nota1    |   Nota2    |   Nota3    |   Nota4    |
#  |     a1     |  Aysha Melanie Gilberto   |    LEI     |     12     |     8      |     19     |     8      |
#  |     a2     |   Igor André Cantanhede   |   ENGFIS   |     12     |     16     |     18     |     20     |
#  |     a3     |     Laurénio Narciso      |   ENGFIS   |     8      |     14     |     15     |     14     |
#  |     a4     |      Jasnoor Casegas      |    LCC     |     14     |     20     |     17     |     11     |
#  |     a5     |     Tawseef Rebouças      |  ENGBIOM   |     13     |     14     |     13     |     17     |
#  |     a6     |      Eryk Clementino      |    LEI     |     10     |     19     |     11     |     14     |
#  |     a7     |        Ianna Noivo        |  ENGBIOM   |     15     |     15     |     17     |     16     |
#  |     a8     |    Ayla Thaissa Reina     |  ENGBIOM   |     12     |     8      |     8      |     18     |
# ...

# %%
cursos = TP7.distCurso(Turma)

cursos
# Out:
# {'LEI': 23, 'ENGFIS': 32, 'LCC': 20, 'ENGBIOM': 25}

# %%
medias = TP7.media(Turma)

print(medias)
# Out:
# {'Aysha Melanie Gilberto': 11.75, 'Igor André Cantanhede': 16.5, 'Laurénio Narciso': 12.75, 'Jasnoor Casegas': 15.5, 'Tawseef Rebouças': 14.25, 'Eryk Clementino': 13.5, 'Ianna Noivo': 15.75, 'Ayla Thaissa Reina': 11.5, 'Cássia Viviane Coitã': 13.0, 'Koby Vindima': 14.0, 'Gustavo Martim Hernandez': 11.0, 'Siddarta Beiriz': 14.75, 'Daniela Patrícia Montes': 16.75, 'Kaylla Pessego': 14.0, 'Bianca Cristina Primitivo': 13.25, 'Magna Galhardo': 15.25, 'Grace Isabel Patriarca': 12.75, 'Saubhagya Buco': 15.25, 'Ivo Vicente Boisa': 13.75, 'Vivaan Castilhos': 13.0, 'Layana Camejo': 14.75, 'Mahdi Menoita': 12.75, 'Yifan Cortinado': 15.25, 'Éder Sodré': 14.0, 'Dhriti Magano': 14.25, 'Steve Devesa': 11.75, 'Lisandro Mariano Picassinos': 12.25, 'Itiel Quinoy': 13.25, 'Pranika Reimoo': 14.0, 'Manaia Viseu': 12.75, 'Eva Manuel Caio': 16.0, 'Ariane Sofia Foja': 17.5, 'Jaime António Pauseiro': 12.5, 'Tanisha Marzagoo': 15.0, 'Siyon Anca': 13.75, 'Diana Beatriz Boavista': 16.5, 'Elisiário Saberio': 1
# ...

# %%
TP7.notas(Turma)
# Out:
# {'Aysha Melanie Gilberto': [11.75],
#  'Igor André Cantanhede': [16.5],
#  'Laurénio Narciso': [12.75],
#  'Jasnoor Casegas': [15.5],
#  'Tawseef Rebouças': [14.25],
#  'Eryk Clementino': [13.5],
#  'Ianna Noivo': [15.75],
#  'Ayla Thaissa Reina': [11.5],
#  'Cássia Viviane Coitã': [13.0],
#  'Koby Vindima': [14.0],
#  'Gustavo Martim Hernandez': [11.0],
#  'Siddarta Beiriz': [14.75],
#  'Daniela Patrícia Montes': [16.75],
#  'Kaylla Pessego': [14.0],
#  'Bianca Cristina Primitivo': [13.25],
#  'Magna Galhardo': [15.25],
#  'Grace Isabel Patriarca': [12.75],
#  'Saubhagya Buco': [15.25],
#  'Ivo Vicente Boisa': [13.75],
#  'Vivaan Castilhos': [13.0],
#  'Layana Camejo': [14.75],
#  'Mahdi Menoita': [12.75],
#  'Yifan Cortinado': [15.25],
#  'Éder Sodré': [14.0],
#  'Dhriti Magano': [14.25],
#  'Steve Devesa': [11.75],
#  'Lisandro Mariano Picassinos': [12.25],
#  'Itiel Quinoy': [13.25],
#  'Pranika Reimoo': [14.0],
#  'Manaia Viseu': [12.75],
#  'Eva Manuel Caio': [16.0],
# ...

# %%
TP7.dictmedias(Turma)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 TP7.dictmedias(Turma)
#
# File c:\Users\liama\OneDrive\Ambiente de Trabalho\UNI\3 ANO\1 SEMESTRE\ALGORITMOS\Ficheiros\2022\PRATICAS\TP7\TP7.py:80, in dictmedias(Turma)
#      75 lista=[]
#      78 for aluno in a.keys():
# ---> 80     if (float(a.values) >= 1 and float(a.values)  <= 4.99):
#      81         escalaoE.append(aluno)
#      83     elif (float(a.values) >= 5 and float(a.values) <= 8.99):
#
# TypeError: float() argument must be a string or a real number, not 'builtin_function_or_method'

# %%
TP7.media1(Turma)
# Out:
# [('a1', 'Aysha Melanie Gilberto', 'LEI', '12', '8', '19', '8', '11.75'),
#  ('a2', 'Igor André Cantanhede', 'ENGFIS', '12', '16', '18', '20', '16.5'),
#  ('a3', 'Laurénio Narciso', 'ENGFIS', '8', '14', '15', '14', '12.75'),
#  ('a4', 'Jasnoor Casegas', 'LCC', '14', '20', '17', '11', '15.5'),
#  ('a5', 'Tawseef Rebouças', 'ENGBIOM', '13', '14', '13', '17', '14.25'),
#  ('a6', 'Eryk Clementino', 'LEI', '10', '19', '11', '14', '13.5'),
#  ('a7', 'Ianna Noivo', 'ENGBIOM', '15', '15', '17', '16', '15.75'),
#  ('a8', 'Ayla Thaissa Reina', 'ENGBIOM', '12', '8', '8', '18', '11.5'),
#  ('a9', 'Cássia Viviane Coitã', 'ENGFIS', '19', '9', '14', '10', '13.0'),
#  ('a10', 'Koby Vindima', 'LEI', '9', '14', '20', '13', '14.0'),
#  ('a11', 'Gustavo Martim Hernandez', 'ENGBIOM', '11', '8', '14', '11', '11.0'),
#  ('a12', 'Siddarta Beiriz', 'LEI', '17', '10', '16', '16', '14.75'),
#  ('a13',
#   'Daniela Patrícia Montes',
#   'ENGBIOM',
#   '15',
#   '15',
#   '18',
#   '19',
#   '16.75'),
# ...

# %%
import TP7

Turma = TP7.le("alunos.csv")

def menu(): 

    opcao = input ('''
        Introduza o que que pretende ver: 
                          
                          (1) Imprimir a informação por colunas;
                          (2) Calcular a distribuição dos alunos por curso;
                          (3) Média numa lista de cada aluno correspondente;
                                                  
                         ''')
         
    return int(opcao)   



def opcoes():
   
    opcao=10
    
    
    while opcao != 0 :
        opcao= menu()
        
        if opcao == 1:
          resultado = TP7.Imprime(Turma)
          print(resultado)
            
        elif opcao == 2:
            resultado = TP7.distCurso(Turma)
            print(resultado)

        if opcao == 3:
          resultado = TP7.notas(Turma)
          print(resultado)
